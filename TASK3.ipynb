# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumya41199/TASKS_GRIP/blob/main/TASK3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AUTHOR: B.SOUMYA
# TASK 3: EXPLORATORY DATA ANALYSIS(RETAIL)
#
# DATASET: SAMPLE SUPERSTORE

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
#checking for null values
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking for Duplicate Values
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates(inplace = True)

# %%
#Looking at the correlation between quantitative features
sns.heatmap(data.corr(),cmap = "YlGnBu")

# %%
sns.pairplot(data)

# %% [markdown]
# #PRODUCT CATEGORIES

# %%
sns.countplot(x = 'Category', hue = 'Region', data = data , palette = 'dark')

# %%
sns.countplot(x = 'Category', hue = 'Segment', data = data , palette = 'dark')

# %% [markdown]
# SUBCATEGORIES

# %%
print(data['Sales'].describe())
# Out:
# count     9977.000000
# mean       230.148902
# std        623.721409
# min          0.444000
# 25%         17.300000
# 50%         54.816000
# 75%        209.970000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,9))                                #plotting the sales column
sns.distplot(data['Sales'],bins=100,color='blue')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ABOVE PLOT SHOWS THE RANGE OF SALES

# %%
data.hist(figsize=(15,15),bins=50,xlabelsize=3,ylabelsize=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f37fae9fef0>,
# ...
#       dtype=object)

# %%
#visualizing count of each sub category
plt.figure(figsize=(10,10))
data['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")

# %% [markdown]
# BY ABOVE PLOT WE CAN SAY PAPERS ANND BINDERS HAVE MORE VARIETY

# %%
#Visualizing Sales with the sub-category
sns.lmplot(x='Category',y='Sales',data=data,fit_reg=False,      #visualising the sales per catogory with
           hue='Sub-Category',legend=True ,                     # its subcategory   
           palette="Set2",size=8,aspect=15/10)
plt.title("Sales per category with its subcategory")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Sales per category with its subcategory')

# %% [markdown]
# By the above plot we can say the technology category has more sales value

# %%
sns.set_style("darkgrid")
sns.countplot(x='Segment',data=data,palette="Set1")

# %%
sns.set_style("darkgrid")
sns.countplot(x='Category',data=data,palette="Set1")

# %%
plt.figure(figsize=(16,10))
sns.set_style("darkgrid")

sns.countplot(x='Sub-Category',data=data,palette="Set3")

# %%
sns.set_style("darkgrid")
sns.countplot(x='Ship Mode',data=data,palette="Set2")

# %%
sns.set_style("darkgrid")
sns.countplot(x="Region",data=data,palette="Set1")

# %%
statewise=data.groupby(['State'])['Sales'].sum()
statewise.sort_values(ascending=False,inplace=True)
fig, ax = plt.subplots(figsize=(20,10))
plt.title('State vs Sales')
statewise.plot.bar()

# %% [markdown]
# From the above bar plot we can say that california has highest no. of sales

# %%
statewise=data.groupby(['State'])['Profit'].sum()
statewise.sort_values(ascending=False,inplace=True)
fig, ax = plt.subplots(figsize=(20,10))
plt.title("State vs Profit")
statewise.plot.bar()

# %% [markdown]
# From the above plot we can say that california and NewYork has more profit

# %%
s=data.groupby('Sub-Category')['Profit','Sales'].agg(['sum'])
s.plot.bar(rot=0, title="Total Profit and sales per category",figsize=(15,10));
plt.show(block=True);
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# By seeing the above bar plot we can say that, copiers have highest profit amongst others and chairs and phones have highest sales while tables and bookcases are in loss.¶

# %% [markdown]
# #INSIGHTS:
# 1.Office Supplies have more variety
#
# 2.Technology has highest sales as compared to other categories.
#
#
# 3.People prefer to use standard shipment mode as compared to other modes.
#
# 4.Corporate segment has highest count as compared to others.
#
#
# 5.Maximum Profit earned from states like California and New York, whereas Texas and Chio gives more loss and products like phones and copiers give more profit , whereas chairs and bookcases are on loss.
